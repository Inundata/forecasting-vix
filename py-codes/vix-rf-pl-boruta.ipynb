# %% [markdown]
# ### Random Forest를 partial linear 모형으로 세워서 vix를 예측해보기
# - $y_{t} = y_{t-1} + y_{t-1}^{weekly} + y_{t-1}^{monthly} + y_{t-1}^{quarterly} + f(X_{t-1})$
#     - $y_{t-1}^{weekly} = \frac{1}{5}\sum^{5}_{j=1}y_{t-j}$
#     - $y_{t-1}^{monthly} = \frac{1}{22}\sum^{22}_{j=1}y_{t-j}$
# - random forest의 경우 default value로 진행하기
# - 동일하게 rolling으로 진행
# - random seed를 하나로 고정하고 진행 → 나의 경우 42

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rc, font_manager, rcParams
font_name = font_manager.FontProperties(fname = "c:/windows/fonts/malgun.ttf").get_name()
rc('font', family = font_name)
rcParams["axes.unicode_minus"] = False

from datetime import datetime
from dateutil.relativedelta import relativedelta

from sklearn.ensemble import RandomForestRegressor
import xgboost
import statsmodels.api as sm

from sklearn.metrics import mean_absolute_error, mean_squared_error

import pickle

from boruta import BorutaPy

# %% [markdown]
# #### Import data

# %%
# Line 7~16
df = pd.read_excel("../data/dataset_HARX(14).xlsx")
RAW_DF = df.copy()
RAW_DF.set_index(["Code"], inplace = True)
df = df.iloc[66:, :]
date = df["Code"].to_numpy() # The date
df.set_index(["Code"], inplace = True)
df = df.iloc[:5740, :] # to 1990-04-06 ~ 2013-01-15
                    # Fernandes et al.(2014) : 1990-04-05 ~ 2013-01-15
                    # But some values are NaN at 1990-04-05
                    # So I dropped 1990-04-05 #TODO: 해당 업은 아래 `run_pl_rf`에서 수행하도록 바꿨음. Forecast horizon을 맞추기 위해서
                                                # 최종적으로 forecast horizon은 Fernandes와 동일함
data = df.to_numpy() # To matrix
# data = data[66:, :] # obsolete line if dropna performed correctly # TODO: 위의 TODO 주석으로 인해서 이 부분은 주석처리함

# %%
df.head(2)
# Out:
#                lnVIX  HAR_5day  HAR_10day  HAR_22day  HAR_66day   SP_1day  \
# Code
# 1990-04-05  3.054473  3.055005   3.021329   2.998303   3.094873 -0.001056
# 1990-04-06  3.080073  3.074592   3.027489   3.004229   3.097588 -0.001909
#
#              SP_5day  SP_10day  SP_22day  SP_66day  ...  SP_66day.1  \
# Code                                                ...
# 1990-04-05 -0.000176  0.014902  0.008252 -0.054152  ...         NaN
# 1990-04-06  0.000412  0.008445  0.009246 -0.053473  ...   -0.054152
#
#             S&PCOMP(MV).1  Oil_1day.1  Oil_5day.1  Oil_10day.1  Oil_22day.1  \
# Code
# 1990-04-05      -0.007446   -0.025950   -0.015053    -0.009059    -0.087096
# 1990-04-06      -0.001156   -0.017853   -0.030413    -0.028914    -0.091889
#
#             Oil_66day.1  T10Y3M.1  Credit Spread.1  USG6WIC(TW).1
# Code
# 1990-04-05          NaN      0.54             0.85      -0.000665
# 1990-04-06    -0.163882      0.55             0.84      -0.000785
#
# [2 rows x 33 columns]

# %%
df.tail(2)
# Out:
#                lnVIX  HAR_5day  HAR_10day  HAR_22day  HAR_66day   SP_1day  \
# Code
# 2013-01-14  2.604170  2.607063   2.654235   2.774609   2.796113 -0.000931
# 2013-01-15  2.606387  2.606033   2.625725   2.767197   2.794462  0.001128
#
#              SP_5day  SP_10day  SP_22day  SP_66day  ...  SP_66day.1  \
# Code                                                ...
# 2013-01-14  0.005995  0.047518  0.029562  0.006652  ...    0.007261
# 2013-01-15  0.010370  0.031846  0.030242  0.011242  ...    0.006652
#
#             S&PCOMP(MV).1  Oil_1day.1  Oil_5day.1  Oil_10day.1  Oil_22day.1  \
# Code
# 2013-01-14      -0.000046   -0.002775    0.005036     0.029173     0.089385
# 2013-01-15      -0.000935    0.006180    0.010143     0.036124     0.092881
#
#             Oil_66day.1  T10Y3M.1  Credit Spread.1  USG6WIC(TW).1
# Code
# 2013-01-14     0.019972      1.82             0.92      -0.002825
# 2013-01-15     0.046308      1.81             0.93      -0.000503
#
# [2 rows x 33 columns]

# %%
# plot vix
plt.plot(df["lnVIX"])
plt.title("Daily plot of VIX")
plt.show()

# %% [markdown]
# #### set the params for forecasting

# %%
npred = 3240

random_state = 42

params_for_rf = {"n_estimators" : 1, "random_state" : random_state}
params_for_xgb = {"tree_method" : "exact", "random_state" : random_state}

linear_variables = ["lnVIX", "HAR_5day", "HAR_10day", "HAR_22day", "HAR_66day"]
nonlinear_variables = list(df.columns[5:])
target_variable = "lnVIX"

# lag = 1

# %% [markdown]
# #### Perform the forecasting

# %%
# tmp_data = df.loc[date_window]

# # perform dropna due to 1990-04-05 / at that days, some variables contain np.nan
# tmp_data.dropna(inplace = True)

# # update date_window in case of dropna
# date_window = date_window[np.isin(date_window, tmp_data.index)]

# # set the X and Y
# Y = tmp_data.loc[:, target_variable]
# X = tmp_data.loc[:, linear_variables + nonlinear_variables]

# # set the target X and y
# X_window = date_window[:-lag]
# y_window = date_window[lag:]

# X_train = X.loc[X_window]
# y_train = Y.loc[y_window]

# # split the X to linear and nonlinear
# X_linear_train = X_train.loc[:, linear_variables]
# X_nonlinear_train = X_train.loc[:, nonlinear_variables]

# # Set the window for test
# X_test_window = date_window[-lag]
# y_test_window = date[(np.where(date == pd.to_datetime(X_test_window))[0] + lag)[0]]

# X_linear_test = tmp_data.loc[X_test_window:X_test_window, linear_variables]
# X_nonlinear_test = tmp_data.loc[X_test_window:X_test_window, nonlinear_variables]

# # Apply the Robison's estimator
# ## 1. extract linear residual
# RF_X_linear_residual = []
# XGB_X_linear_residual = []

# for idx in range(X_linear_train.shape[1]):
    
#     tmp_X_linear = X_linear_train.iloc[:, idx:idx+1]

#     # Random Forest
#     RF_for_residual_X_linear = RandomForestRegressor(**params_for_rf)
#     RF_for_residual_X_linear.fit(X = X_nonlinear_train, y = tmp_X_linear.values.ravel())

#     tmp_RF_X_linear_residual = tmp_X_linear.iloc[:, 0] - RF_for_residual_X_linear.predict(X_nonlinear_train)
#     RF_X_linear_residual.append(tmp_RF_X_linear_residual)

#     # XGBoost
#     XGB_for_residual_X_linear = xgboost.XGBRegressor(**params_for_xgb)
#     XGB_for_residual_X_linear.fit(X = X_nonlinear_train, y = tmp_X_linear.values.ravel())

#     tmp_XGB_X_linear_residual = tmp_X_linear.iloc[:, 0] - XGB_for_residual_X_linear.predict(X_nonlinear_train)
#     XGB_X_linear_residual.append(tmp_XGB_X_linear_residual)

# RF_X_linear_residual = pd.concat(RF_X_linear_residual, axis = 1)
# XGB_X_linear_residual = pd.concat(XGB_X_linear_residual, axis = 1)

# ## 2. extract y residual
# # Random Forest
# RF_for_residual_y = RandomForestRegressor(**params_for_rf)
# RF_for_residual_y.fit(X = X_nonlinear_train, y = y_train.values.ravel())
# RF_y_residual = y_train - RF_for_residual_y.predict(X_nonlinear_train)

# # XGBoost
# XGB_for_residual_y = xgboost.XGBRegressor(**params_for_xgb)
# XGB_for_residual_y.fit(X = X_nonlinear_train, y = y_train.values.ravel())
# XGB_y_residual = y_train - XGB_for_residual_y.predict(X_nonlinear_train)

# ## 3. Get the beta
# RF_beta = pd.DataFrame(index = X_window, columns = RF_X_linear_residual.columns)
# XGB_beta = pd.DataFrame(index = X_window, columns = XGB_X_linear_residual.columns)

# RF_OLS = sm.OLS(endog = RF_y_residual.values, exog = RF_X_linear_residual.values).fit()
# XGB_OLS = sm.OLS(endog = XGB_y_residual.values, exog = XGB_X_linear_residual.values).fit()

# RF_beta = RF_OLS.params
# XGB_beta = XGB_OLS.params

# ## 4. Estimate RandomForest and XGBoost
# RF_residual = y_train.ravel() - (X_linear_train @ RF_beta).ravel()
# XGB_residual = y_train.ravel() - (X_linear_train @ XGB_beta).ravel()

# RF_ = RandomForestRegressor(**params_for_rf)
# RF_.fit(X = X_nonlinear_train, y = RF_residual)

# XGB_ = xgboost.XGBRegressor(**params_for_xgb)
# XGB_.fit(X = X_nonlinear_train, y = XGB_residual)

# ## 5. Get the prediction
# RF_pred = X_linear_test @ RF_beta + RF_.predict(X_nonlinear_test)
# XGB_pred = X_linear_test @ XGB_beta + XGB_.predict(X_nonlinear_test)

# RF_pred.index = [y_test_window]
# XGB_pred.index = [y_test_window]

# RF_pred.name = "VIX_pred_RF"
# XGB_pred.name = "VIX_pred_XGB"

# %%
"""define the func `run_pl_rf`"""
def run_pl_rf(date_window, date, lag, df, linear_variables, nonlinear_variables, target_variable):

    tmp_data = df.loc[date_window]

    # perform dropna due to 1990-04-05 / at that days, some variables contain np.nan
    tmp_data.dropna(inplace = True)

    # update date_window in case of dropna
    date_window = date_window[np.isin(date_window, tmp_data.index)]

    # set the X and Y
    Y = tmp_data.loc[:, target_variable]
    X = tmp_data.loc[:, linear_variables + nonlinear_variables]

    # set the target X and y
    X_window = date_window[:-lag]
    y_window = date_window[lag:]

    X_train = X.loc[X_window]
    y_train = Y.loc[y_window]

    # split the X to linear and nonlinear
    X_linear_train = X_train.loc[:, linear_variables]
    X_nonlinear_train = X_train.loc[:, nonlinear_variables]

    # Set the window for test
    # X_test_window = date_window[-lag]
    X_test_window = date_window[-1]
    y_test_window = date[(np.where(date == pd.to_datetime(X_test_window))[0] + lag)[0]]

    X_linear_test = tmp_data.loc[X_test_window:X_test_window, linear_variables]
    X_nonlinear_test = tmp_data.loc[X_test_window:X_test_window, nonlinear_variables]

    # Apply the Robison's estimator
    ## 1. extract linear residual
    RF_X_linear_residual = []
    XGB_X_linear_residual = []

    for idx in range(X_linear_train.shape[1]):
        
        tmp_X_linear = X_linear_train.iloc[:, idx:idx+1]

        # Random Forest
        RF_for_residual_X_linear = RandomForestRegressor(**params_for_rf)
        RF_for_residual_X_linear.fit(X = X_nonlinear_train, y = tmp_X_linear.values.ravel())

        tmp_RF_X_linear_residual = tmp_X_linear.iloc[:, 0] - RF_for_residual_X_linear.predict(X_nonlinear_train)
        RF_X_linear_residual.append(tmp_RF_X_linear_residual)

        # XGBoost
        XGB_for_residual_X_linear = xgboost.XGBRegressor(**params_for_xgb)
        XGB_for_residual_X_linear.fit(X = X_nonlinear_train, y = tmp_X_linear.values.ravel())

        tmp_XGB_X_linear_residual = tmp_X_linear.iloc[:, 0] - XGB_for_residual_X_linear.predict(X_nonlinear_train)
        XGB_X_linear_residual.append(tmp_XGB_X_linear_residual)

    RF_X_linear_residual = pd.concat(RF_X_linear_residual, axis = 1)
    XGB_X_linear_residual = pd.concat(XGB_X_linear_residual, axis = 1)

    ## 2. extract y residual
    # Random Forest
    RF_for_residual_y = RandomForestRegressor(**params_for_rf)
    RF_for_residual_y.fit(X = X_nonlinear_train, y = y_train.values.ravel())
    RF_y_residual = y_train - RF_for_residual_y.predict(X_nonlinear_train)

    # XGBoost
    XGB_for_residual_y = xgboost.XGBRegressor(**params_for_xgb)
    XGB_for_residual_y.fit(X = X_nonlinear_train, y = y_train.values.ravel())
    XGB_y_residual = y_train - XGB_for_residual_y.predict(X_nonlinear_train)

    ## 3. Get the beta
    RF_beta = pd.DataFrame(index = X_window, columns = RF_X_linear_residual.columns)
    XGB_beta = pd.DataFrame(index = X_window, columns = XGB_X_linear_residual.columns)

    RF_OLS = sm.OLS(endog = RF_y_residual.values, exog = RF_X_linear_residual.values).fit()
    XGB_OLS = sm.OLS(endog = XGB_y_residual.values, exog = XGB_X_linear_residual.values).fit()

    RF_beta = RF_OLS.params
    XGB_beta = XGB_OLS.params

    ## 4. Estimate RandomForest and XGBoost
    RF_residual = y_train.ravel() - (X_linear_train @ RF_beta).ravel()
    XGB_residual = y_train.ravel() - (X_linear_train @ XGB_beta).ravel()

    RF_ = RandomForestRegressor(**params_for_rf)
    RF_.fit(X = X_nonlinear_train, y = RF_residual)

    XGB_ = xgboost.XGBRegressor(**params_for_xgb)
    XGB_.fit(X = X_nonlinear_train, y = XGB_residual)

    ## 5. Get the prediction
    RF_pred = X_linear_test @ RF_beta + RF_.predict(X_nonlinear_test)
    XGB_pred = X_linear_test @ XGB_beta + XGB_.predict(X_nonlinear_test)

    RF_pred.index = [y_test_window]
    XGB_pred.index = [y_test_window]

    RF_pred.name = "VIX_pred_RF"
    XGB_pred.name = "VIX_pred_XGB"

    return RF_pred, XGB_pred, RF_beta, XGB_beta

# %%
df.loc[datetime(2000, 2, 28), "lnVIX"]
# Out:
# 3.205993199037187

# %%
df.iloc[2490:2510]
# Out:
#                lnVIX  HAR_5day  HAR_10day  HAR_22day  HAR_66day   SP_1day  \
# Code
# 2000-02-14  3.193763  3.143038   3.129849   3.123174   3.108205  0.002031
# 2000-02-15  3.132010  3.158169   3.127563   3.125640   3.108648  0.008675
# 2000-02-16  3.157426  3.163427   3.129236   3.133769   3.109606 -0.010309
# 2000-02-17  3.142858  3.164292   3.134372   3.137169   3.110634  0.000425
# 2000-02-18  3.258097  3.176831   3.153190   3.145344   3.112664 -0.030847
# 2000-02-22  3.252697  3.188618   3.165828   3.153212   3.116014  0.004507
# 2000-02-23  3.173460  3.196908   3.177538   3.159464   3.117996  0.006281
# 2000-02-24  3.193763  3.204175   3.183801   3.160046   3.121180 -0.005350
# 2000-02-25  3.226844  3.220972   3.192632   3.164158   3.125371 -0.014940
# 2000-02-28  3.205993  3.210552   3.193691   3.167304   3.128572  0.010957
# 2000-02-29  3.151453  3.190303   3.189460   3.166974   3.130192  0.013535
# 2000-03-01  3.074543  3.170519   3.183713   3.158387   3.131191  0.009302
# 2000-03-02  3.047376  3.141242   3.172708   3.150682   3.130303  0.001862
# 2000-03-03  2.955431  3.086959   3.153966   3.141617   3.127204  0.019643
# 2000-03-06  3.068053  3.059371   3.134961   3.138315   3.125424 -0.012777
# 2000-03-07  3.190888  3.067258   3.128780   3.142833   3.126780 -0.025965
# 2000-03-08  3.170526  3.086455   3.128487   3.147406   3.128143  0.008140
# 2000-03-09  3.100543  3.097088   3.119165   3.146234   3.130255  0.025280
# 2000-03-10  3.055886  3.117179   3.102069   3.146213   3.130734 -0.004734
# 2000-03-13  3.128951  3.129359   3.094365   3.146113   3.131948 -0.008241
#
#              SP_5day  SP_10day  SP_22day  SP_66day  ...  SP_66day.1  \
# Code                                                ...
# 2000-02-14 -0.024378 -0.003247 -0.029986  0.017901  ...    0.007315
# 2000-02-15 -0.027901 -0.005143 -0.033407  0.020602  ...    0.017901
# 2000-02-16 -0.017169 -0.015339 -0.054332  0.004485  ...    0.020602
# 2000-02-17 -0.020371 -0.026100 -0.047051 -0.005603  ...    0.004485
# 2000-02-18 -0.030026 -0.056526 -0.078420 -0.035253  ...   -0.005603
# 2000-02-22 -0.027550 -0.051928 -0.066793 -0.048995  ...   -0.035253
# 2000-02-23 -0.029944 -0.057845 -0.057595 -0.036101  ...   -0.048995
# 2000-02-24 -0.024984 -0.042153 -0.034922 -0.051488  ...   -0.036101
# 2000-02-25 -0.040349 -0.060720 -0.055909 -0.064362  ...   -0.051488
# 2000-02-28  0.001455 -0.028571 -0.040730 -0.052660  ...   -0.064362
# 2000-02-29  0.010483 -0.017066 -0.023249 -0.027587  ...   -0.052660
# 2000-03-01  0.013504 -0.016439  0.013894 -0.027102  ...   -0.027587
# 2000-03-02  0.020716 -0.004268 -0.009149 -0.024916  ...   -0.027102
# 2000-03-03  0.055299  0.014950 -0.000078  0.000951  ...   -0.024916
# 2000-03-06  0.031565  0.033020 -0.012741  0.001705  ...    0.000951
# 2000-03-07 -0.007935  0.002548 -0.049892 -0.030583  ...    0.001705
# 2000-03-08 -0.009097  0.004407 -0.041331 -0.030510  ...   -0.030583
# 2000-03-09  0.014321  0.035037 -0.015960 -0.022301  ...   -0.030510
# 2000-03-10 -0.010056  0.045243 -0.032892 -0.020055  ...   -0.022301
# 2000-03-13 -0.005521  0.026044 -0.020091 -0.018298  ...   -0.020055
#
#             S&PCOMP(MV).1  Oil_1day.1  Oil_5day.1  Oil_10day.1  Oil_22day.1  \
# Code
# 2000-02-14      -0.021194    0.000340    0.021285     0.078402     0.133143
# 2000-02-15       0.002035    0.027142    0.061348     0.090232     0.140688
# 2000-02-16       0.008675   -0.006301    0.070277     0.063164     0.118906
# 2000-02-17      -0.010313   -0.000333    0.043529     0.086860     0.069944
# 2000-02-18       0.000442   -0.019829    0.001019     0.049758     0.020923
# 2000-02-22      -0.030844    0.001696    0.002375     0.023660    -0.001016
# 2000-02-23       0.004506    0.003721   -0.021046     0.040302    -0.001350
# 2000-02-24       0.006283   -0.007795   -0.022541     0.047736     0.041333
# 2000-02-25      -0.002921    0.019542   -0.002666     0.040864     0.074082
# 2000-02-28      -0.014937    0.012600    0.029763     0.030782     0.070642
# 2000-02-29       0.010968   -0.007275    0.020792     0.023167     0.079048
# 2000-03-01       0.013480    0.009908    0.026979     0.005933     0.107810
# 2000-03-02       0.009301    0.043093    0.077868     0.055327     0.154570
# 2000-03-03       0.001857   -0.002521    0.055804     0.053139     0.136737
# 2000-03-06       0.019854   -0.023305    0.019900     0.049663     0.092665
# 2000-03-07      -0.012777    0.038649    0.065824     0.086616     0.155343
# 2000-03-08      -0.025971    0.058832    0.114748     0.141727     0.196901
# 2000-03-09       0.008145   -0.087837   -0.016183     0.061685     0.081270
# 2000-03-10       0.025274    0.013662    0.000000     0.055804     0.107853
# 2000-03-13      -0.004731    0.002206    0.025512     0.045411     0.125289
#
#             Oil_66day.1  T10Y3M.1  Credit Spread.1  USG6WIC(TW).1
# Code
# 2000-02-14     0.235189      0.97             0.62      -0.000576
# 2000-02-15     0.230193      0.88             0.63       0.006123
# 2000-02-16     0.205748      0.81             0.64      -0.001909
# 2000-02-17     0.211153      0.83             0.63      -0.004214
# 2000-02-18     0.167764      0.84             0.62       0.000576
# 2000-02-22     0.160667      0.74             0.61       0.002873
# 2000-02-23     0.141959      0.54             0.62      -0.011833
# 2000-02-24     0.099743      0.62             0.61       0.001161
# 2000-02-25     0.149822      0.55             0.61       0.006168
# 2000-02-28     0.133390      0.57             0.63       0.011273
# 2000-02-29     0.107095      0.57             0.63       0.000380
# 2000-03-01     0.140551      0.64             0.64       0.006625
# 2000-03-02     0.167512      0.63             0.63      -0.009573
# 2000-03-03     0.164991      0.64             0.64       0.007874
# 2000-03-06     0.176139      0.60             0.64       0.002736
# 2000-03-07     0.269005      0.57             0.64       0.000188
# 2000-03-08     0.311301      0.56             0.64      -0.002075
# 2000-03-09     0.191190      0.55             0.65       0.000472
# 2000-03-10     0.205239      0.53             0.66      -0.004635
# 2000-03-13     0.175043      0.52             0.67       0.001610
#
# [20 rows x 33 columns]

# %%
from functools import reduce

RF_prediction_dict = {}
XGB_prediction_dict = {}

RF_betas_dict = {}
XGB_betas_dict = {}

RF_rmse_dict = {}
XGB_rmse_dict = {}

RF_mae_dict = {}
XGB_mae_dict = {}

for lag in [1, 5, 10, 22][:]:

    print("{0:=^30}".format(f" Start {lag}-ahead forecast "))

    RF_prediction = []
    XGB_prediction = []

    RF_betas = []
    XGB_betas = []
    for i in range(npred, 0, -1)[:]:
        
        date_window = date[(npred - i):(data.shape[0] - i)]

        pred_idx = npred - i

        # perform the forecast
        RF_pred, XGB_pred, RF_beta, XGB_beta = run_pl_rf(date_window, date, lag, df
                                                        , linear_variables, nonlinear_variables
                                                        , target_variable)
        
        # run_pl_rf(date_window, date, lag, df
        #         , linear_variables, nonlinear_variables
        #         , target_variable)
        
        RF_prediction.append(RF_pred)
        XGB_prediction.append(XGB_pred)

        RF_betas.append(RF_beta)
        XGB_betas.append(XGB_beta)

        if (pred_idx+1)%20 == 0:
            print(f"Forecast #{pred_idx}-th sample is finished.")

    # to DataFrame
    RF_prediction = pd.concat(RF_prediction).to_frame()
    XGB_prediction = pd.concat(XGB_prediction).to_frame()

    RF_betas = pd.DataFrame(RF_betas, columns = linear_variables, index = RF_prediction.index)
    XGB_betas = pd.DataFrame(XGB_betas, columns = linear_variables, index = XGB_prediction.index)

    # change the column name to identify from which lag
    RF_prediction.columns = [RF_prediction.columns[0] + f"_lag{lag}"]
    XGB_prediction.columns = [XGB_prediction.columns[0] + f"_lag{lag}"]

    # get the real value to calculate errors
    real_value = RAW_DF[[target_variable]].loc[RF_prediction.index]

    # merge the prediction
    result = reduce(lambda l, r: pd.merge(l, r, left_index = True, right_index = True)
                                        , [real_value, RF_prediction, XGB_prediction])

    # calculate errors
    RF_rmse = mean_squared_error(result["lnVIX"], result[f"VIX_pred_RF_lag{lag}"], squared = False)
    XGB_rmse = mean_squared_error(result["lnVIX"], result[f"VIX_pred_XGB_lag{lag}"], squared = False)

    RF_mae = mean_absolute_error(result["lnVIX"], result[f"VIX_pred_RF_lag{lag}"])
    XGB_mae = mean_absolute_error(result["lnVIX"], result[f"VIX_pred_XGB_lag{lag}"])

    # Save the result
    RF_prediction_dict[lag], XGB_prediction_dict[lag] = RF_prediction, XGB_prediction
    RF_betas_dict[lag], XGB_betas_dict[lag] = RF_betas, XGB_betas
    RF_rmse_dict[lag], XGB_rmse_dict[lag] = RF_rmse, XGB_rmse
    RF_mae_dict[lag], XGB_mae_dict[lag] = RF_mae, XGB_mae
# Out:
# === Start 1-ahead forecast ===

# %%
result_dict = {"RF_prediction" : RF_prediction_dict, "XGB_prediction" : XGB_prediction_dict
            , "RF_rmse" : RF_rmse_dict, "XGB_rmse" : XGB_rmse_dict
            , "RF_mae" : RF_mae_dict, "XGB_mae" : XGB_mae_dict
            , "RF_betas" : RF_betas_dict, "XGB_betas" : XGB_betas_dict}

# %%
from pathlib import Path

data_path = str(Path.cwd().parent / "data")
result_path = str(Path.cwd().parent / "result")

# %%
import pickle

with open(f"{result_path}/vix-forecast-py_241003.pkl", "wb") as f:
    pickle.dump(result_dict, f)

# %% [markdown]
# #### Boruta 알고리즘 적용해보기

# %%
from functools import reduce

RF_prediction_dict = {}
XGB_prediction_dict = {}

RF_betas_dict = {}
XGB_betas_dict = {}

RF_rmse_dict = {}
XGB_rmse_dict = {}

RF_mae_dict = {}
XGB_mae_dict = {}

feat_selects = {}
for lag in [1, 5, 10, 22][:]:
    if lag not in feat_selects.keys():
        feat_selects[lag] = {}

    print("{0:=^30}".format(f" Start {lag}-ahead forecast "))

    RF_prediction = []
    XGB_prediction = []

    RF_betas = []
    XGB_betas = []
    for i in range(npred, 0, -1)[:1]:
        
        date_window = date[(npred - i):(data.shape[0] - i)]

        pred_idx = npred - i

        # perform the forecast
        # RF_pred, XGB_pred, RF_beta, XGB_beta = run_pl_rf(date_window, date, lag, df
        #                                                 , linear_variables, nonlinear_variables
        #                                                 , target_variable)

        tmp_data = df.loc[date_window]

        # perform dropna due to 1990-04-05 / at that days, some variables contain np.nan
        tmp_data.dropna(inplace = True)

        # update date_window in case of dropna
        date_window = date_window[np.isin(date_window, tmp_data.index)]

        # set the X and Y
        Y = tmp_data.loc[:, target_variable]
        X = tmp_data.loc[:, linear_variables + nonlinear_variables]

        # set the target X and y
        X_window = date_window[:-lag]
        y_window = date_window[lag:]

        X_train = X.loc[X_window]
        y_train = Y.loc[y_window]

        # split the X to linear and nonlinear
        X_linear_train = X_train.loc[:, linear_variables]
        X_nonlinear_train = X_train.loc[:, nonlinear_variables]

        # Set the window for test
        # X_test_window = date_window[-lag]
        X_test_window = date_window[-1]
        y_test_window = date[(np.where(date == pd.to_datetime(X_test_window))[0] + lag)[0]]

        X_linear_test = tmp_data.loc[X_test_window:X_test_window, linear_variables]
        X_nonlinear_test = tmp_data.loc[X_test_window:X_test_window, nonlinear_variables]

        # Apply the Robison's estimator
        ## 1. extract linear residual
        RF_X_linear_residual = []
        XGB_X_linear_residual = []

        
        for idx in range(X_linear_train.shape[1]):
            
            tmp_X_linear = X_linear_train.iloc[:, idx:idx+1]

            # Random Forest
            tmp_params_for_rf = params_for_rf.copy()
            tmp_params_for_rf.update({"max_depth" : 5})
            RF_for_residual_X_linear = RandomForestRegressor(**tmp_params_for_rf)
            RF_for_residual_X_linear_feat_select = BorutaPy(RF_for_residual_X_linear
                                                        , n_estimators = "auto"
                                                        , verbose = 2
                                                        , random_state = 42)
            RF_for_residual_X_linear_feat_select.fit(X_nonlinear_train, y = tmp_X_linear.values.ravel())
            
            feat_selects[lag][idx] = RF_for_residual_X_linear_feat_select

            # RF_for_residual_X_linear.fit(X = X_nonlinear_train, y = tmp_X_linear.values.ravel())

            # tmp_RF_X_linear_residual = tmp_X_linear.iloc[:, 0] - RF_for_residual_X_linear.predict(X_nonlinear_train)
            # RF_X_linear_residual.append(tmp_RF_X_linear_residual)
# Out:
# === Start 1-ahead forecast ===
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	19
# Tentative: 	9
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	19
# Tentative: 	9
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	19
# Tentative: 	8
# Rejected: 	1
# Iteration: 	11 / 100
# Confirmed: 	19
# Tentative: 	8
# Rejected: 	1
# Iteration: 	12 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	13 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	14 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	15 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	16 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	17 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	18 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	19 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	20 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	21 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	22 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	23 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	24 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	25 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	26 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	27 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	28 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	29 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	30 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	31 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	32 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	33 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	34 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	35 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	36 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	37 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	38 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	39 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	40 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	41 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	42 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	43 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	44 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	45 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	46 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	47 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	48 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	49 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	50 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	51 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	52 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	53 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	54 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	55 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	56 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	57 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	58 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	59 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	60 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	61 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	62 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	63 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	64 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	65 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	66 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	67 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	68 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	69 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	70 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	71 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	72 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	73 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	74 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	75 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	76 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	77 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	78 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	79 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	80 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	81 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	82 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	83 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	84 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	85 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	86 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	87 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	88 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	89 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	90 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	91 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	92 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	93 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	94 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	95 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	96 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	97 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	98 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	99 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	24
# Tentative: 	3
# Rejected: 	1
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	11 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	12 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	13 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	14 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	15 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	16 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	17 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	18 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	19 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	24 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	25 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	26 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	27 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	28 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	29 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	30 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	31 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	32 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	33 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	34 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	35 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	36 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	37 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	38 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	39 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	40 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	41 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	42 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	43 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	44 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	45 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	46 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	47 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	48 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	49 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	50 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	51 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	52 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	53 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	54 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	55 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	56 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	57 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	58 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	59 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	60 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	61 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	62 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	63 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	64 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	65 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	66 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	67 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	68 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	69 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	70 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	71 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	72 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	73 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	74 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	75 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	76 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	77 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	78 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	79 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	80 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	81 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	82 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	83 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	84 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	85 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	86 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	87 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	88 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	89 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	90 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	91 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	92 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	93 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	94 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	95 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	96 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	97 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	98 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	99 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	21
# Tentative: 	2
# Rejected: 	5
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	19
# Tentative: 	9
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	19
# Tentative: 	7
# Rejected: 	2
# Iteration: 	10 / 100
# Confirmed: 	19
# Tentative: 	7
# Rejected: 	2
# Iteration: 	11 / 100
# Confirmed: 	19
# Tentative: 	7
# Rejected: 	2
# Iteration: 	12 / 100
# Confirmed: 	20
# Tentative: 	6
# Rejected: 	2
# Iteration: 	13 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	14 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	15 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	16 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	17 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	18 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	19 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	20 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	21 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	22 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	23 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	24 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	25 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	26 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	27 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	28 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	29 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	30 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	31 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	32 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	33 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	34 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	35 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	36 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	37 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	38 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	39 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	40 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	41 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	42 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	43 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	44 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	45 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	46 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	47 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	48 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	49 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	50 / 100
# Confirmed: 	20
# Tentative: 	5
# Rejected: 	3
# Iteration: 	51 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	52 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	53 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	54 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	55 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	56 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	57 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	58 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	59 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	60 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	61 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	62 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	63 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	64 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	65 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	66 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	67 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	68 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	69 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	70 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	71 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	72 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	73 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	74 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	75 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	76 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	77 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	78 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	79 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	80 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	81 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	82 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	83 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	84 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	85 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	86 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	87 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	88 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	89 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	90 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	91 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	92 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	93 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	94 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	95 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	96 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	97 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	98 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	99 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	15
# Tentative: 	9
# Rejected: 	4
# Iteration: 	9 / 100
# Confirmed: 	15
# Tentative: 	9
# Rejected: 	4
# Iteration: 	10 / 100
# Confirmed: 	15
# Tentative: 	9
# Rejected: 	4
# Iteration: 	11 / 100
# Confirmed: 	15
# Tentative: 	9
# Rejected: 	4
# Iteration: 	12 / 100
# Confirmed: 	17
# Tentative: 	7
# Rejected: 	4
# Iteration: 	13 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	14 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	15 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	16 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	17 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	18 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	19 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	20 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	21 / 100
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	5
# Iteration: 	22 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	23 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	24 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	25 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	26 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	27 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	28 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	29 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	30 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	31 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	6
# Iteration: 	32 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	33 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	34 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	35 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	36 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	37 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	38 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	39 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	40 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	41 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	42 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	43 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	44 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	45 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	46 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	47 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	48 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	49 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	50 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	51 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	52 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	53 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	54 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	55 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	56 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	57 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	58 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	59 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	60 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	61 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	62 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	63 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	64 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	65 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	66 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	67 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	68 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	69 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	70 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	71 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	6
# Iteration: 	72 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	73 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	74 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	75 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	76 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	77 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	78 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	79 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	80 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	81 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	82 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	83 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	84 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	7
# Iteration: 	85 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	86 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	87 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	88 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	89 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	90 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	91 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	92 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	93 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	94 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	8
# Iteration: 	95 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	8
# Iteration: 	96 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	8
# Iteration: 	97 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	8
# Iteration: 	98 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	8
# Iteration: 	99 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	8
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	19
# Tentative: 	0
# Rejected: 	9
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	12
# Tentative: 	9
# Rejected: 	7
# Iteration: 	9 / 100
# Confirmed: 	12
# Tentative: 	9
# Rejected: 	7
# Iteration: 	10 / 100
# Confirmed: 	12
# Tentative: 	9
# Rejected: 	7
# Iteration: 	11 / 100
# Confirmed: 	12
# Tentative: 	9
# Rejected: 	7
# Iteration: 	12 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	13 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	14 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	15 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	16 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	17 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	18 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	19 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	20 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	21 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	22 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	23 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	24 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	25 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	26 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	27 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	28 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	29 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	30 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	31 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	32 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	33 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	34 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	35 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	36 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	37 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	38 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	39 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	40 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	41 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	42 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	43 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	44 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	45 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	46 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	47 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	48 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	49 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	50 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	51 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	52 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	53 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	54 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	55 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	56 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	57 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	58 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	59 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	60 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	61 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	62 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	63 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	64 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	65 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	66 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	67 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	68 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	69 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	70 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	71 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	72 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	73 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	74 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	75 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	76 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	77 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	78 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	79 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	80 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	81 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	82 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	83 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	84 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	85 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	86 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	87 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	88 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	89 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	90 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	91 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	92 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	93 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	94 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	95 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	96 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	97 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	98 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	99 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	15
# Tentative: 	2
# Rejected: 	11
# === Start 5-ahead forecast ===
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	18
# Tentative: 	10
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	18
# Tentative: 	10
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	1
# Iteration: 	11 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	1
# Iteration: 	12 / 100
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	1
# Iteration: 	13 / 100
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	1
# Iteration: 	14 / 100
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	1
# Iteration: 	15 / 100
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	1
# Iteration: 	16 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	17 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	18 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	19 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	20 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	21 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	22 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	23 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	24 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	25 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	26 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	27 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	28 / 100
# Confirmed: 	21
# Tentative: 	6
# Rejected: 	1
# Iteration: 	29 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	30 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	31 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	32 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	33 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	34 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	35 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	36 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	37 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	38 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	39 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	40 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	41 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	42 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	43 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	44 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	45 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	46 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	47 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	48 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	49 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	50 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	51 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	52 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	53 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	54 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	55 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	56 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	57 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	58 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	59 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	60 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	61 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	62 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	63 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	64 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	65 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	66 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	67 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	68 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	69 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	70 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	71 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	72 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	73 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	74 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	75 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	76 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	77 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	78 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	79 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	80 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	81 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	82 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	83 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	84 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	85 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	86 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	87 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	88 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	89 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	90 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	91 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	92 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	1
# Iteration: 	93 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	94 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	95 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	96 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	97 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	98 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
# Iteration: 	99 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	1
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	4
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	15 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	16 / 100
# Confirmed: 	20
# Tentative: 	8
# Rejected: 	0
# Iteration: 	17 / 100
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	1
# Iteration: 	18 / 100
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	1
# Iteration: 	19 / 100
# Confirmed: 	20
# Tentative: 	7
# Rejected: 	1
# Iteration: 	20 / 100
# Confirmed: 	20
# Tentative: 	6
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	20
# Tentative: 	6
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	21
# Tentative: 	5
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	24 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	25 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	26 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	27 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	28 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	29 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	30 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	31 / 100
# Confirmed: 	21
# Tentative: 	4
# Rejected: 	3
# Iteration: 	32 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	33 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	34 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	35 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	36 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	37 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	38 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	39 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	40 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	41 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	42 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	43 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	44 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	45 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	46 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	47 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	48 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	49 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	50 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	51 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	52 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	53 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	54 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	55 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	56 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	57 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	58 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	59 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	60 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	61 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	62 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	63 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	64 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	65 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	66 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	67 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	68 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	69 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	70 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	71 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	72 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	73 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	74 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	75 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	76 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	77 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	78 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	79 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	80 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	81 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	82 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	83 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	84 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	85 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	86 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	87 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	88 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	89 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	90 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	91 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	92 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	93 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	94 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	95 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	96 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	97 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	98 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
# Iteration: 	99 / 100
# Confirmed: 	21
# Tentative: 	3
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	21
# Tentative: 	2
# Rejected: 	5
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	3
# Iteration: 	9 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	3
# Iteration: 	10 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	3
# Iteration: 	11 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	3
# Iteration: 	12 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	3
# Iteration: 	13 / 100
# Confirmed: 	18
# Tentative: 	6
# Rejected: 	4
# Iteration: 	14 / 100
# Confirmed: 	18
# Tentative: 	6
# Rejected: 	4
# Iteration: 	15 / 100
# Confirmed: 	18
# Tentative: 	6
# Rejected: 	4
# Iteration: 	16 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	17 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	18 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	19 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	20 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	21 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	22 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	23 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	24 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	25 / 100
# Confirmed: 	19
# Tentative: 	5
# Rejected: 	4
# Iteration: 	26 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	27 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	28 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	29 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	30 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	31 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	32 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	33 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	34 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	35 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	36 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	37 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	38 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	39 / 100
# Confirmed: 	20
# Tentative: 	4
# Rejected: 	4
# Iteration: 	40 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	41 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	42 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	43 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	44 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	45 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	46 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	47 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	48 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	49 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	50 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	51 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	52 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	53 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	54 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	55 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	56 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	57 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	58 / 100
# Confirmed: 	20
# Tentative: 	3
# Rejected: 	5
# Iteration: 	59 / 100
# ...
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	49 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	50 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	51 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	52 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	53 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	54 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	55 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	56 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	57 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	58 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	59 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	60 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	61 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	62 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	63 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	64 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	65 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	66 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	67 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	68 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	69 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	70 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	71 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	72 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	73 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	74 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	75 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	76 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	77 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	78 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	79 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	80 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	81 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	82 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	83 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	84 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	85 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	86 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	87 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	88 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	89 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	90 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	91 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	92 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	93 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	94 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	95 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	96 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	97 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	98 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
# Iteration: 	99 / 100
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	6
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	7
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	14
# Tentative: 	10
# Rejected: 	4
# Iteration: 	9 / 100
# Confirmed: 	14
# Tentative: 	10
# Rejected: 	4
# Iteration: 	10 / 100
# Confirmed: 	14
# Tentative: 	10
# Rejected: 	4
# Iteration: 	11 / 100
# Confirmed: 	14
# Tentative: 	10
# Rejected: 	4
# Iteration: 	12 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	6
# Iteration: 	13 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	6
# Iteration: 	14 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	6
# Iteration: 	15 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	6
# Iteration: 	16 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	6
# Iteration: 	17 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	6
# Iteration: 	18 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	6
# Iteration: 	19 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	7
# Iteration: 	20 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	7
# Iteration: 	21 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	7
# Iteration: 	22 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	7
# Iteration: 	23 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	7
# Iteration: 	24 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	7
# Iteration: 	25 / 100
# Confirmed: 	17
# Tentative: 	4
# Rejected: 	7
# Iteration: 	26 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	27 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	28 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	29 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	30 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	31 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	32 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	33 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	34 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	35 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	36 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	37 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	38 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	39 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	40 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	41 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	42 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	43 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	44 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	45 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	46 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	47 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	48 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	49 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	50 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	51 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	52 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	53 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	54 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	55 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	56 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	57 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	58 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	59 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	60 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	61 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	62 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	63 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	64 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	65 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	66 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	67 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	68 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	69 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	70 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	71 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	72 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	73 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	74 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	75 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	76 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	77 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	78 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	79 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	80 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	81 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	82 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	83 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	84 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	85 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	86 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	87 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	88 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	89 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	90 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	91 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	92 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	93 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	94 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	95 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	96 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	97 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	98 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
# Iteration: 	99 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	7
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	19
# Tentative: 	0
# Rejected: 	9
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	28
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	5
# Iteration: 	9 / 100
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	5
# Iteration: 	10 / 100
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	5
# Iteration: 	11 / 100
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	5
# Iteration: 	12 / 100
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	5
# Iteration: 	13 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	6
# Iteration: 	14 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	6
# Iteration: 	15 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	6
# Iteration: 	16 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	17 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	18 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	19 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	20 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	21 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	22 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	23 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	24 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	25 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	26 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	27 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	28 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	29 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	30 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	31 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	32 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	33 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	34 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	35 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	36 / 100
# Confirmed: 	14
# Tentative: 	7
# Rejected: 	7
# Iteration: 	37 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	38 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	39 / 100
# Confirmed: 	15
# Tentative: 	6
# Rejected: 	7
# Iteration: 	40 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	41 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	42 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	43 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	44 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	45 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	46 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	47 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	48 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	49 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	50 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	51 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	52 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	53 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	54 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	55 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	56 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	57 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	58 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	59 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	60 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	61 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	62 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	63 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	64 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	65 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	66 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	67 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	68 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	69 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	70 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	71 / 100
# Confirmed: 	15
# Tentative: 	5
# Rejected: 	8
# Iteration: 	72 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	73 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	74 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	75 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	76 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	77 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	78 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	79 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	80 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	81 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	82 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	83 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	84 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	85 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	86 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	87 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	88 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	89 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	90 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	91 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	92 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	93 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	94 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	95 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	96 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	97 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	98 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
# Iteration: 	99 / 100
# Confirmed: 	16
# Tentative: 	4
# Rejected: 	8
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	16
# Tentative: 	3
# Rejected: 	9

# %%
for lag in list(feat_selects.keys())[:]:

    rows, cols = 3, 2
    row_idx, col_idx = 0, 0
    f, ax = plt.subplots(rows, cols, figsize = (20, 12))
    for idx, linear_col in enumerate(X_linear_train):
        green_area = X_nonlinear_train.columns[feat_selects[lag][idx].support_].tolist()
        blue_area = X_nonlinear_train.columns[feat_selects[lag][idx].support_weak_].tolist()

        feat_importances = feat_selects[lag][idx].ranking_

        plt.suptitle(f"{lag}-step ahead forecast", fontweight = "bold", size = 20)
        ax[row_idx, col_idx].bar(X_nonlinear_train.columns, feat_importances, color = 'grey') #모든 특징 중요도
        ax[row_idx, col_idx].bar(green_area, [1]*len(green_area), color = 'green', label='Confirmed Important')
        ax[row_idx, col_idx].bar(blue_area, [2]*len(blue_area), color = 'blue', label = 'Not Confirmed Important')
        ax[row_idx, col_idx].tick_params(axis = "x", rotation = 90)
        ax[row_idx, col_idx].set_title(f"{linear_col}")

        ax[row_idx, col_idx].legend()

        col_idx +=1

        if (col_idx // cols):
            col_idx = 0

            row_idx +=1

    plt.subplots_adjust(hspace = 0.8)
    plt.show()
